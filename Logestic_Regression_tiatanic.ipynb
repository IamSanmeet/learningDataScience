# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('/Users/sanmeetsingh/Downloads/titanic/train.csv')
test_df = pd.read_csv('/Users/sanmeetsingh/Downloads/titanic/test.csv')

# %%
train_df.head(n=3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
train_df.shape
# Out:
# (891, 12)

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(687/891 )
print(177/891)
# Out:
# 0.7710437710437711
# 0.19865319865319866

# %%
print (train_df['Age'].mean(skipna=True))
print (train_df['Age'].median(skipna=True))
print(train_df['Embarked'].value_counts().idxmax())
# Out:
# 29.69911764705882
# 28.0
# S

# %% [markdown]
# ##### we will use meadian because 2 distribution will be in the center (n/2+n+1/2)/2)

# %%
dataset = train_df

# %%
dataset['Age'].fillna(train_df['Age'].median(skipna=True), inplace = True)
dataset['Embarked'].fillna(train_df['Embarked'].value_counts().idxmax(),inplace =True)
dataset.drop('Cabin' , axis=1 , inplace = True)

# %%
dataset.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
dataset['Company'] = np.where((dataset['SibSp'] + dataset['Parch']) > 0,1,0)

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.drop('SibSp' , axis =1 , inplace=True)
dataset.drop('Parch' , axis= 1, inplace = True)

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
dataset.drop('Name' ,  axis =1, inplace =True)
dataset.drop('PassengerId' ,  axis =1 , inplace =True)
dataset.drop('Ticket' ,  axis =1 , inplace =True)

# %%
dataset
# Out:
#      Survived  Pclass     Sex   Age     Fare Embarked  Company
# 0           0       3    male  22.0   7.2500        S        1
# 1           1       1  female  38.0  71.2833        C        1
# 2           1       3  female  26.0   7.9250        S        0
# 3           1       1  female  35.0  53.1000        S        1
# 4           0       3    male  35.0   8.0500        S        0
# ..        ...     ...     ...   ...      ...      ...      ...
# 886         0       2    male  27.0  13.0000        S        0
# 887         1       1  female  19.0  30.0000        S        0
# 888         0       3  female  28.0  23.4500        S        1
# 889         1       1    male  26.0  30.0000        C        0
# 890         0       3    male  32.0   7.7500        Q        0
#
# [891 rows x 7 columns]

# %%
train_X = pd.get_dummies(dataset,columns=['Embarked' , 'Sex'])

# %%
train_X.head()
# Out:
#    Survived  Pclass   Age     Fare  Company  Embarked_C  Embarked_Q  \
# 0         0       3  22.0   7.2500        1       False       False
# 1         1       1  38.0  71.2833        1        True       False
# 2         1       3  26.0   7.9250        0       False       False
# 3         1       1  35.0  53.1000        1       False       False
# 4         0       3  35.0   8.0500        0       False       False
#
#    Embarked_S  Sex_female  Sex_male
# 0        True       False      True
# 1       False        True     False
# 2        True        True     False
# 3        True        True     False
# 4        True       False      True

# %%
train_X['Embarked_C'] = np.where(train_X['Embarked_C']==True , 1,0)

# %%
train_X['Embarked_Q'] = np.where(train_X['Embarked_C']==True , 1,0)

# %%
train_X['Embarked_C'] = np.where(train_X['Embarked_C']==True , 1,0)
train_X['Sex_female'] = np.where(train_X['Embarked_C']==True , 1,0)
train_X['Sex_male'] = np.where(train_X['Embarked_C']==True , 1,0)

# %%
train_X
# Out:
#      Survived  Pclass   Age     Fare  Company  Embarked_C  Embarked_Q  \
# 0           0       3  22.0   7.2500        1           0           0
# 1           1       1  38.0  71.2833        1           1           1
# 2           1       3  26.0   7.9250        0           0           0
# 3           1       1  35.0  53.1000        1           0           0
# 4           0       3  35.0   8.0500        0           0           0
# ..        ...     ...   ...      ...      ...         ...         ...
# 886         0       2  27.0  13.0000        0           0           0
# 887         1       1  19.0  30.0000        0           0           0
# 888         0       3  28.0  23.4500        1           0           0
# 889         1       1  26.0  30.0000        0           1           1
# 890         0       3  32.0   7.7500        0           0           0
#
#      Embarked_S  Sex_female  Sex_male
# 0          True           0         0
# 1         False           1         1
# ...

# %%
train_Y = train_X['Survived']
train_X.drop('Survived', axis =1,inplace=True)

# %%
##Test Dataset

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset= test_df

# %%
dataset['Age'].fillna(test_df['Age'].median(skipna=True), inplace = True)
dataset['Fare'].fillna(test_df['Age'].median(skipna=True), inplace = True)
dataset['Embarked'].fillna(test_df['Embarked'].value_counts().idxmax(),inplace =True)
dataset.drop('Cabin' , axis=1 , inplace = True)

# %%
dataset
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
dataset['Company'] = np.where((dataset['SibSp'] + dataset['Parch']) > 0,1,0)
dataset.drop('SibSp' , axis =1 , inplace=True)
dataset.drop('Parch' , axis= 1, inplace = True)

# %%
dataset
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age              Ticket      Fare Embarked  Company
# ...

# %%
test_dataset = pd.get_dummies(dataset,columns=['Embarked' , 'Sex'])

# %%
test_dataset['Embarked_C'] = np.where(test_dataset ['Embarked_C']==True , 1,0)

# %%
test_dataset ['Embarked_Q'] = np.where(test_dataset ['Embarked_C']==True , 1,0)

# %%
test_dataset['Embarked_C'] = np.where(test_dataset ['Embarked_C']==True , 1,0)
test_dataset['Embarked_S'] = np.where(test_dataset ['Embarked_C']==True , 1,0)
test_dataset['Sex_female'] = np.where(test_dataset ['Embarked_C']==True , 1,0)
test_dataset['Sex_male'] = np.where(test_dataset ['Embarked_C']==True , 1,0)

# %%
dataset
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age              Ticket      Fare Embarked  Company
# ...

# %%
def sigmoid(X):
    return 1/(1 + np.exp(-X))

# %%
def hypothesis(X, theta):
    return sigmoid(np.dot(X, theta))

# %%
def cost(X, Y, theta):
    hx = hypothesis(X, theta)
    loss = np.mean(Y*np.log(hx) + (1-Y)*np.log(1-hx))
    return -1*loss

# %%
def gradient(X, Y, theta):
    y_p = hypothesis(X, theta)
    grad = np.dot(X.T, (Y - y_p))
    return grad/X.shape[0]

# %%
def gradient_descent(X, Y):
    theta = np.zeros((X.shape[1], ))
    
    max_epochs = 5000
    epoch_loss = []
    lr = 0.00388
    
    for i in range(max_epochs):
        grad = gradient(X, Y, theta)
        
        loss = cost(X, Y, theta)
        epoch_loss.append(loss)
        
        theta = theta + lr*grad
        
    return theta, epoch_loss

# %%
train_X = train_X.values
train_Y = train_Y.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 2
#       1 train_X = train_X.values
# ----> 2 train_Y = train_Y.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
type(train_X) , type(train_Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 type(train_X) , type(Y_train)
#
# NameError: name 'Y_train' is not defined

# %%
print(Y_train.shape)

# %%
theta , epoch_loss  = gradient_descent(train_X , Y_train)

# %%
epoch_loss[-10:]
